# %%
#%matplotlib qt  
# %matplotlib inline

import time
start_time = time.time()

import math
import scipy
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import *
import pandas as pd
import seaborn as sns
from scipy.stats import norm
from scipy.stats import zscore

plt.style.use("default")

my_data_1 = np.loadtxt('336_475_1.2_color-mag')
x_data_1 = my_data_1[:,2]   # f336w - f475w
y_data_1 = my_data_1[:,0]   # f336w

my_data_2 = np.loadtxt('475_814_1.2_color-mag')
x_data_2 = my_data_2[:,2]   # f475w - f814w
y_data_2 = my_data_2[:,0]   # f475w 

my_data_3 = np.loadtxt('336_814_1.2_color-mag')
x_data_3 = my_data_3[:,2]   # f336w - f814w
y_data_3 = my_data_3[:,0]   # f336w

isochrone_data_1 = np.loadtxt('ngc411_0.25_9.20_0.002_isochrone')
x_iso_1 = isochrone_data_1[:,3]
y_iso_1 = isochrone_data_1[:,0]

x_iso_2 = isochrone_data_1[:,4]                        
y_iso_2 = isochrone_data_1[:,1]
                            
x_iso_3 = isochrone_data_1[:,5]
y_iso_3 = isochrone_data_1[:,0]

isochrone_data_2 = np.loadtxt('ngc411_0.25_9.22_0.002')
x_iso_11 = isochrone_data_2[:,3]
y_iso_11 = isochrone_data_2[:,0]

x_iso_21 = isochrone_data_2[:,4]                        
y_iso_21 = isochrone_data_2[:,1]
                            
x_iso_31 = isochrone_data_2[:,5]
y_iso_31 = isochrone_data_2[:,0]

isochrone_data_3 = np.loadtxt('ngc411_0.25_9.18_0.003') # green
x_iso_12 = isochrone_data_3[:,3]
y_iso_12 = isochrone_data_3[:,0]

x_iso_22 = isochrone_data_3[:,4]                        
y_iso_22 = isochrone_data_3[:,1]
                            
x_iso_32 = isochrone_data_3[:,5]
y_iso_32 = isochrone_data_3[:,0]


#isochrone_data_4 = np.loadtxt('ngc411_0.25_9.18_0.006') # (Doesn't work)
isochrone_data_4 = np.loadtxt('ngc411_0.25_9.18_0.002') #blue
x_iso_13 = isochrone_data_4[:,3]
y_iso_13 = isochrone_data_4[:,0]

x_iso_23 = isochrone_data_4[:,4]                        
y_iso_23 = isochrone_data_4[:,1]
                            
x_iso_33 = isochrone_data_4[:,5]
y_iso_33 = isochrone_data_4[:,0]
#c_index = np.loadtxt('all_three')
#c_index_x = c_index[:,9]
#c_index_y = c_index[:,4]

print("********* THIS IS CMD FOR NGC 411 ************")
plt.figure()
plt.scatter(x_data_1, y_data_1, 0.3, 'black')
plt.plot(x_iso_1, y_iso_1, linewidth=0.5, c='yellow')
plt.plot(x_iso_11, y_iso_11,linewidth= 0.5, c='red')
plt.plot(x_iso_12, y_iso_12,linewidth= 1.5, c='green')
plt.plot(x_iso_13, y_iso_13,linewidth= 0.5, c='blue')
plt.xlim(-1.5, 2.0)
plt.ylim(18, 24.5)
plt.gca().invert_yaxis()
plt.xlabel("F336W - F475W (mag)", fontsize=20)
plt.ylabel("F336W (mag)", fontsize=20)
#plt.title('CMD of NGC 411 for F336W and F475W', fontsize=12)
plt.show()

                        
plt.figure()
plt.scatter(x_data_2, y_data_2, 0.3, 'black')
plt.plot(x_iso_2, y_iso_2,linewidth= 0.5, c='yellow')
plt.plot(x_iso_21, y_iso_21,linewidth= 0.5, c='red')
plt.plot(x_iso_22, y_iso_22,linewidth= 1.5, c='green')
plt.plot(x_iso_23, y_iso_23,linewidth= 0.5, c='blue')
plt.xlim(-1.3, 3.5)
plt.ylim(18, 24.5)
plt.gca().invert_yaxis()
plt.xlabel("F475W - F814W (mag)", fontsize=20)
plt.ylabel("F475W (mag)", fontsize=20)
#plt.title('CMD of NGC 411 for F475W and F814W', fontsize=12)
plt.show() 

plt.figure()
plt.scatter(x_data_3, y_data_3, 0.3, 'black')
plt.plot(x_iso_3, y_iso_3,linewidth= 0.5, c='yellow')
plt.plot(x_iso_31, y_iso_31,linewidth= 0.5, c='red')
plt.plot(x_iso_32, y_iso_32,linewidth= 1.5, c='green')
plt.plot(x_iso_33, y_iso_33, linewidth=0.5, c='blue')
plt.xlim(-1.2 , 2.2)
plt.ylim(18, 24.5)
plt.gca().invert_yaxis()
plt.xlabel("F336W - F814W (mag)", fontsize=20)
plt.ylabel("F336W (mag)", fontsize=20)
#plt.title('CMD of NGC 411 for F336W and F814W', fontsize=12)
plt.show()

"""
plt.figure()
plt.scatter(c_index_x, c_index_y,0.3, 'black')
plt.xlim(-1.3 , 3.5)
plt.ylim(18, 24.5)
plt.gca().invert_yaxis()
plt.xlabel("F336W - F814W (mag)", fontsize=20)
plt.ylabel("F336W (mag)", fontsize=20)
plt.title('CMD of NGC 411 for F336W and F814W', fontsize=12)
plt.show()
"""
print('loading of data is completed in [{}] seconds'.format(time.time() - start_time))
# Out:
# ********* THIS IS CMD FOR NGC 411 ************
# loading of data is completed in [8.487019777297974] seconds

# %%
#fig, ax = plt.subplots(2)
#ax.scatter(x_data_3, y_data_3, 0.3, 'black')

#ax[0].scatter(x_data_3, y_data_3, 0.3, 'black')
#ax[1].scatter(x_data_3, y_data_3, 0.3, 'black')
#fig.suptitle('Vertically stacked subplots')

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
#fig.suptitle('Colour Magnitude Diagrams for NGC 411')
fig.tight_layout() 
fig.set_size_inches(19.0, 8.5) 
ax1.scatter(x_data_1, y_data_1, 0.7, 'black')
ax1.plot(x_iso_1, y_iso_1, linewidth=0.5, c='yellow')
ax1.plot(x_iso_11, y_iso_11,linewidth= 0.5, c='red')
ax1.plot(x_iso_12, y_iso_12,linewidth= 0.5, c='green')
ax1.plot(x_iso_13, y_iso_13,linewidth= 0.5, c='blue')
ax1.set_xlim(-1.2,2.0)
ax1.set_ylim(18, 24.0)
ax1.invert_yaxis()
ax1.set_xlabel("F336W - F475W (mag)", fontsize=15.5)
ax1.set_ylabel("F336W (mag)", fontsize=15.5)

ax2.scatter(x_data_2, y_data_2, 0.7, 'black')
ax2.plot(x_iso_2, y_iso_2,linewidth= 0.5, c='yellow')
ax2.plot(x_iso_21, y_iso_21,linewidth= 0.5, c='red')
ax2.plot(x_iso_22, y_iso_22,linewidth= 0.5, c='green')
ax2.plot(x_iso_23, y_iso_23,linewidth= 0.5, c='blue')
ax2.set_xlim(-1.2,2.2)
ax2.set_ylim(18, 24.2)
ax2.invert_yaxis()
ax2.set_xlabel("F475W - F814W (mag)", fontsize=15.5)
ax2.set_ylabel("F475W (mag)", fontsize=15.5)

ax3.scatter(x_data_3, y_data_3, 0.7, 'black')
ax3.plot(x_iso_3, y_iso_3,linewidth= 0.5, c='yellow')
ax3.plot(x_iso_31, y_iso_31,linewidth= 0.5, c='red')
ax3.plot(x_iso_32, y_iso_32,linewidth= 0.5, c='green')
ax3.plot(x_iso_33, y_iso_33, linewidth=0.5, c='blue')
ax3.set_xlim(-1.2,3.8)
ax3.set_ylim(18, 24.5)
ax3.invert_yaxis()
ax3.set_xlabel("F336W - F814W (mag)", fontsize=15.5)
ax3.set_ylabel("F336W (mag)", fontsize=15.5) 

fig.tight_layout(pad=3.0) 


#fig.text(0.5, 0.04, 'common X', ha='center')
#fig.text(0.04, 0.5, 'common Y', va='center', rotation='vertical')

# %%
c_index = np.loadtxt('C_Index_NGC411')
first = c_index[:,0]   # f336w - f475w
second = c_index[:,1]   # f336w
third = c_index[:,2]
final = c_index[:,6]

plt.style.use("default")
plt.figure()
plt.scatter(final,first, 0.3, 'black')
plt.xlim(-1.5, 0.3)
plt.ylim(16.5, 24.0)
plt.gca().invert_yaxis()
plt.xlabel("C_Index (mag)", fontsize=20)
plt.ylabel("F336W (mag)", fontsize=20)
plt.title('C Index of NGC 411 for F336W and F475W', fontsize=12)
plt.show()

plt.figure()
plt.scatter(final,second, 0.3, 'black')
plt.xlim(-1.5, 0.3)
plt.ylim(16.5, 24.0)
plt.gca().invert_yaxis()
plt.xlabel("C_Index (mag)", fontsize=20)
plt.ylabel("F475W (mag)", fontsize=20)
plt.title('C Index of NGC 411 for F336W and F475W', fontsize=12)
plt.show()

plt.figure()
plt.scatter(final,third, 0.3, 'black')
plt.xlim(-1.5, 0.3)
plt.ylim(16.5, 23.0)
plt.gca().invert_yaxis()
plt.xlabel("C_Index (mag)", fontsize=20)
plt.ylabel("F814W (mag)", fontsize=20)
plt.title('C Index of NGC 411 for F336W and F475W', fontsize=12)
plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
#fig.suptitle('Colour Magnitude Diagrams for NGC 411')
fig.tight_layout() 

ax1.scatter(x_data_1, y_data_1, 0.1, 'black')
ax2.scatter(x_data_2, y_data_2, 0.1, 'black')
ax3.scatter(x_data_3, y_data_3, 0.1, 'black')

ax1.set_xlim(-1.2,1.8)
ax1.set_ylim(18, 24.0)
ax1.invert_yaxis()
ax1.set_xlabel("F336W - F475W (mag)", fontsize=8.5)
ax1.set_ylabel("F336W (mag)", fontsize=8.5)

ax2.set_xlim(-1.2,2.3)
ax2.set_ylim(18, 24.5)
ax2.invert_yaxis()
ax2.set_xlabel("F475W - F814W (mag)", fontsize=8.5)
ax2.set_ylabel("F475W (mag)", fontsize=8.5)

ax3.set_xlim(-1.2,3.3)
ax3.set_ylim(18, 24.5)
ax3.invert_yaxis()
ax3.set_xlabel("F336W - F814W (mag)", fontsize=8.5)
ax3.set_ylabel("F336W (mag)", fontsize=8.5) 

#fig.text(0.5, 0.04, 'common X', ha='center')
#fig.text(0.04, 0.5, 'common Y', va='center', rotation='vertical')
# Out:
# Text(392.83986928104576, 0.5, 'F336W (mag)')

# %%
#%matplotlib qt  
# %matplotlib inline

import time
start_time = time.time()

import math
import scipy
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import *
import pandas as pd
import seaborn as sns
from scipy.stats import norm
from scipy.stats import zscore

plt.style.use("default")

my_data_1 = np.loadtxt('336_475_1.2_color-mag')
x_data_1 = my_data_1[:,2]   # f336w - f475w
y_data_1 = my_data_1[:,0]   # f336w

my_data_2 = np.loadtxt('475_814_1.2_color-mag')
x_data_2 = my_data_2[:,2]   # f475w - f814w
y_data_2 = my_data_2[:,0]   # f475w 

my_data_3 = np.loadtxt('336_814_1.2_color-mag')
x_data_3 = my_data_3[:,2]   # f336w - f814w
y_data_3 = my_data_3[:,0]   # f336w

isochrone_data = np.loadtxt('ngc_411_Av_0.19_2')
x_iso_1 = isochrone_data[:,3]
y_iso_1 = isochrone_data[:,0]

x_iso_2 = isochrone_data[:,4]                        
y_iso_2 = isochrone_data[:,1]
                            
x_iso_3 = isochrone_data[:,5]
y_iso_3 = isochrone_data[:,0]                            
                            
#c_index = np.loadtxt('all_three')
#c_index_x = c_index[:,9]
#c_index_y = c_index[:,4]

print("********* THIS IS CMD FOR NGC 411 ************")
plt.figure()
plt.scatter(x_data_1, y_data_1, 0.3, 'black')
plt.plot(x_iso_1, y_iso_1, 1.5)
plt.xlim(-1.5, 2.0)
plt.ylim(18, 24.5)
plt.gca().invert_yaxis()
plt.xlabel("F336W - F475W (mag)", fontsize=20)
plt.ylabel("F336W (mag)", fontsize=20)
plt.title('CMD of NGC 411 for F336W and F475W', fontsize=12)
plt.show()

                        
plt.figure()
plt.scatter(x_data_2, y_data_2, 0.3, 'black')
plt.plot(x_iso_2, y_iso_2, 1.5)
plt.xlim(-1.3, 3.5)
plt.ylim(18, 24.5)
plt.gca().invert_yaxis()
plt.xlabel("F475W - F814W (mag)", fontsize=20)
plt.ylabel("F475W (mag)", fontsize=20)
plt.title('CMD of NGC 411 for F475W and F814W', fontsize=12)
plt.show() 


#isochrone_data_336_814=np.loadtxt('336_814_Av_0.19_iso') 
#x_iso_3 = isochrone_data_336_814[:,2]
#y_iso_3 = isochrone_data_336_814[:,0]   

plt.figure()
plt.scatter(x_data_3, y_data_3, 0.3, 'black')
plt.plot(x_iso_3, y_iso_3, 1.5)
plt.xlim(-1.3 , 3.5)
plt.ylim(18, 24.5)
plt.gca().invert_yaxis()
plt.xlabel("F336W - F814W (mag)", fontsize=20)
plt.ylabel("F336W (mag)", fontsize=20)
plt.title('CMD of NGC 411 for F336W and F814W', fontsize=12)
plt.show()

"""
plt.figure()
plt.scatter(c_index_x, c_index_y,0.3, 'black')
plt.xlim(-1.3 , 3.5)
plt.ylim(18, 24.5)
plt.gca().invert_yaxis()
plt.xlabel("F336W - F814W (mag)", fontsize=20)
plt.ylabel("F336W (mag)", fontsize=20)
plt.title('CMD of NGC 411 for F336W and F814W', fontsize=12)
plt.show()
"""
print('loading of data is completed in [{}] seconds'.format(time.time() - start_time))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-55da390c9d66> in <module>
#      30 y_data_3 = my_data_3[:,0]   # f336w
#      31
# ---> 32 isochrone_data = np.loadtxt('ngc_411_Av_0.19_2')
#      33 x_iso_1 = isochrone_data[:,3]
#      34 y_iso_1 = isochrone_data[:,0]
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     966             fname = os_fspath(fname)
#     967         if _is_string_like(fname):
# --> 968             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     969             fencoding = getattr(fh, 'encoding', 'latin1')
#     970             fh = iter(fh)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     267
# ...

# %%
# ***************************F336W and F475W****************************************************
plt.style.use('default')
# For F336W and F475W filters:
first_df = pd.DataFrame({'x_data_1':x_data_1, 'y_data_1':y_data_1})
#print(first_df)
first_df_cut = first_df[(first_df['x_data_1']<=1.4) & (first_df['x_data_1']>= 0.38) & (first_df['y_data_1']<=22.1) & (first_df['y_data_1']>=19.1)]
#print(first_df_cut)
first_df_cut_index = first_df_cut[(first_df_cut.x_data_1 < 0.67) & (first_df_cut.y_data_1 < 20.8)].index.to_numpy()
first_df_cut_1 = first_df_cut.drop(first_df_cut_index)


plt.figure()
plt.grid()
plt.scatter(first_df_cut.x_data_1, first_df_cut.y_data_1,  2.5, 'black')
plt.xlim(0.2,1.7)
plt.ylim(18.0, 22.7)
plt.xlabel('m_F336W - m_F475W (mag)', fontsize=15)
plt.ylabel('m_F336W (mag)', fontsize=15)
plt.title("RGB of NGC 411 for F336W and F475W", fontsize=12)
plt.gca().invert_yaxis()
plt.show()

plt.figure()
plt.grid()
plt.scatter(first_df_cut_1.x_data_1, first_df_cut_1.y_data_1, 2.2, 'black')
plt.xlim(0.2,1.7)
plt.ylim(18.0, 22.7)
plt.xlabel('m_F336W - m_F475W (mag)', fontsize=15)
plt.ylabel('m_F336W (mag)', fontsize=15)
plt.title("RGB without Red Clump (RC)", fontsize=15)
plt.gca().invert_yaxis()
plt.show()

#define a dataframe for x data and y data
first_df_new= pd.DataFrame({'x_data_1':first_df_cut_1.x_data_1,'y_data_1':first_df_cut_1.y_data_1})
#print(df_new)

first_df1_new = first_df_new[(first_df_new['x_data_1']<=1.4) & (first_df_new['x_data_1']>= 0.25) & (first_df_new['y_data_1']<=21.5) & (first_df_new['y_data_1']>=19.9)]
#print(df1_new)
bins = np.linspace(19.9,21.5, num=6) # These are number of bins

md_1 = pd.DataFrame(np.zeros(((len(bins)-1), 2)), columns=['x_med','y_med'])
#print(md)

for i in range(len(bins)-1):
    tempdf = first_df1_new[(first_df1_new['y_data_1'] >= bins[i]) & (first_df1_new['y_data_1'] <= bins[i+1]) ]
    x_median = np.median(tempdf['x_data_1'])
    y_median = np.median(tempdf['y_data_1'])
    md_1.iloc[i]=[x_median, y_median]
    
#print(md)

plt.figure()
plt.plot(md_1['x_med'], md_1['y_med'], 'black')
plt.grid()
plt.scatter(first_df1_new['x_data_1'], first_df1_new['y_data_1'], 2.2, 'black', zorder=0) # zorder= is used when you are lazy. 
plt.xlim(0.2, 1.7)
plt.ylim(18, 22)
plt.xlabel('m_F336W - m_F475W (mag)', fontsize=15)
plt.ylabel('m_F336W (mag)', fontsize=15)
plt.title("Fiducial line through RGB", fontsize=20)
plt.gca().invert_yaxis() # Again. When you are lazy, use this. Being lazy is good and easy. 
plt.show()

first_a = pd.cut(first_df1_new.y_data_1, bins)
first_b = first_df1_new.groupby(['y_data_1', first_a]).y_data_1.median()

first_df2 = pd.DataFrame({'values':first_b})
np.savetxt('cut_group_1.txt', first_df2)

first_df1_new['x_diff_new_1'] = first_df1_new.groupby(first_a).apply(lambda grp: grp.x_data_1 - grp.x_data_1.median()).values
plt.hist(first_df1_new.x_diff_new_1,bins=87,  cumulative=False,histtype='step',orientation='vertical' )
plt.title('Histogram: Distance Distribution from the Fiducial Line', fontsize=12)
plt.xlabel('Pixel Distance' ,fontsize=20)
plt.ylabel('Number of Stars', fontsize=20)
#plt.xlim(-0.20, 0.21)
plt.show()
# ******************************************End of F336W and F475W*****
# Out:
# /home/shalmalee/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# ******************************************Start of F475W and F814W**************************************

# For F475W and F814W filters 
second_df = pd.DataFrame({'x_data_2':x_data_2, 'y_data_2':y_data_2})
#print(second_df)
second_df_cut = second_df[(second_df['x_data_2']<=2.2 ) & (second_df['x_data_2']>=1.2) & (second_df['y_data_2']<=21.3) & (second_df['y_data_2']>=18)]
#print(second_df_cut)
second_df_cut_index = second_df_cut[(second_df_cut.x_data_2 < 1.4) & (second_df_cut.y_data_2 <20.3 )].index.to_numpy()
second_df_cut_1 = second_df_cut.drop(second_df_cut_index)


plt.figure()
plt.grid()
#plt.scatter(x_data_2, y_data_2, 0.3, 'red')
plt.scatter(second_df_cut.x_data_2, second_df_cut.y_data_2, 2.0, 'black')
plt.xlim(0.9,2.1)
plt.ylim(17.9, 21.5)
plt.xlabel('m_F475W - F814W (mag)', fontsize=15)
plt.ylabel('m_F475W (mag)', fontsize=15)
plt.title("RGB of NGC 411 for F475W and F814W", fontsize=12)
plt.gca().invert_yaxis()
plt.show()

plt.figure()
plt.grid()
plt.scatter(second_df_cut_1.x_data_2, second_df_cut_1.y_data_2, 2.0, 'black')
plt.xlim(0.9,2.1)
plt.ylim(17.9, 21.5)
plt.xlabel('m_F475W - m_F814W (mag)', fontsize=15)
plt.ylabel('m_F475W (mag)', fontsize=15)
plt.title("RGB without Red Clump (RC)", fontsize=15)
plt.gca().invert_yaxis()
plt.show()

#define a dataframe for x data and y data
second_df_new= pd.DataFrame({'x_data_2':second_df_cut_1.x_data_2,'y_data_2':second_df_cut_1.y_data_2})
#print(df_new)

second_df1_new = second_df_new[(second_df_new['x_data_2']<=1.9) & (second_df_new['x_data_2']>=0.25 ) & (second_df_new['y_data_2']<=22.0) & (second_df_new['y_data_2']>=18.0)]
#print(df1_new)
bins = np.linspace(18,21.5, num=6) # These are number of bins

md_2 = pd.DataFrame(np.zeros(((len(bins)-1), 2)), columns=['x_med','y_med'])
#print(md)

for i in range(len(bins)-1):
    tempdf = second_df1_new[(second_df1_new['y_data_2'] >= bins[i]) & (second_df1_new['y_data_2'] <= bins[i+1]) ]
    x_median = np.median(tempdf['x_data_2'])
    y_median = np.median(tempdf['y_data_2'])
    md_2.iloc[i]=[x_median, y_median]
    
#print(md)
plt.figure()
plt.plot(md_2['x_med'], md_2['y_med'], 'black')
plt.grid()
plt.scatter(second_df1_new['x_data_2'], second_df1_new['y_data_2'], 2.0, 'black', zorder=0) # zorder= is used when you are lazy. 
plt.xlim(1.2, 1.9)
plt.ylim(17.7, 21.5)
plt.xlabel('m_F475W - m_F814W (mag)', fontsize=15)
plt.ylabel('m_F475W (mag)', fontsize=15)
plt.title("Fiducial line through RGB", fontsize=20)
plt.gca().invert_yaxis() # Again. When you are lazy, use this. Being lazy is good and easy. 
plt.show()

second_a = pd.cut(second_df1_new.y_data_2, bins)
second_b = second_df1_new.groupby(['y_data_2', second_a]).y_data_2.median()

second_df2 = pd.DataFrame({'values':second_b})
np.savetxt('cut_group_1.txt', second_df2)

second_df1_new['x_diff_new_2'] = second_df1_new.groupby(second_a).apply(lambda grp: grp.x_data_2 - grp.x_data_2.median()).values
plt.hist(second_df1_new.x_diff_new_2, bins=47,histtype='step')
plt.title('Histogram: Distance Distribution from the Fiducial Line', fontsize=12)
plt.xlabel('Pixel Distance' ,fontsize=20)
plt.ylabel('Number of Stars', fontsize=20)
#plt.xlim(-0.20, 0.21)
plt.show()
# ********************************************End of F475W and F814W***
# Out:
# /home/shalmalee/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# ********************************************Start of F336W and F814W**************************************************

# For F336W and F814W filters
third_df = pd.DataFrame({'x_data_3':x_data_3, 'y_data_3':y_data_3})
#print(third_df)
third_df_cut = third_df[(third_df['x_data_3']<=3.5) & (third_df['x_data_3']>= 1.6) & (third_df['y_data_3']<=22) & (third_df['y_data_3']>=19.8)]
#print(third_df_cut)
third_df_cut_index = third_df_cut[(third_df_cut.x_data_3 < 2.1) & (third_df_cut.y_data_3 < 20.76)].index.to_numpy()
third_df_cut_1 = third_df_cut.drop(third_df_cut_index)
print(len(third_df_cut_1))

plt.figure()
plt.grid()
plt.scatter(third_df_cut.x_data_3, third_df_cut.y_data_3, 2.0, 'black')
plt.xlim(1.0,3.6)
plt.ylim(19.5, 22.3)
plt.xlabel('m_F475W - F814W (mag)', fontsize=15)
plt.ylabel('m_F475W (mag)', fontsize=15)
plt.title("RGB of NGC 411 for F336W and F814W", fontsize=12)
plt.gca().invert_yaxis()
plt.show()

plt.figure()
plt.grid()
plt.scatter(third_df_cut_1.x_data_3, third_df_cut_1.y_data_3, 2.0, 'black')
plt.xlim(1.0,3.6)
plt.ylim(19.5, 22.3)
plt.xlabel('m_F475W - m_F814W (mag)', fontsize=15)
plt.ylabel('m_F475W (mag)', fontsize=15)
plt.title("RGB without Red Clump (RC)", fontsize=15)
plt.gca().invert_yaxis()
plt.show()

#define a dataframe for x data and y data
third_df_new= pd.DataFrame({'x_data_3':third_df_cut_1.x_data_3,'y_data_3':third_df_cut_1.y_data_3})
#print(df_new)

third_df1_new = third_df_new[(third_df_new['x_data_3']<=3.5) & (third_df_new['x_data_3']>= 1.5) & (third_df_new['y_data_3']<=22) & (third_df_new['y_data_3']>=19.5)]
print(len(third_df1_new))
bins = np.linspace(19.5,22.3, num=7) # These are number of bins

md_3 = pd.DataFrame(np.zeros(((len(bins)-1), 2)), columns=['x_med','y_med'])
#print(md)

for i in range(len(bins)-1):
    tempdf = third_df1_new[(third_df1_new['y_data_3'] >= bins[i]) & (third_df1_new['y_data_3'] <= bins[i+1]) ]
    x_median = np.median(tempdf['x_data_3'])
    y_median = np.median(tempdf['y_data_3'])
    md_3.iloc[i]=[x_median, y_median]
    
#print(md)

plt.figure()
plt.plot(md_3['x_med'], md_3['y_med'], 'black')
plt.grid()
plt.scatter(third_df1_new['x_data_3'], third_df1_new['y_data_3'], 2.0, 'black', zorder=0) # zorder= is used when you are lazy. 
#plt.xlim(1.45, 3.5)
#plt.ylim(19.7, 21.9)
plt.xlabel('m_F336W - m_F814W (mag)', fontsize=15)
plt.ylabel('m_F336W (mag)', fontsize=15)
plt.title("Fiducial line through RGB", fontsize=20)
plt.gca().invert_yaxis() # Again. When you are lazy, use this. Being lazy is good and easy. 
plt.show()

third_a = pd.cut(third_df1_new.y_data_3, bins)
third_b = third_df1_new.groupby(['y_data_3', third_a]).y_data_3.median()

third_df2 = pd.DataFrame({'values':third_b})
np.savetxt('cut_group_1.txt', third_df2)

third_df1_new['x_diff_new_3'] = third_df1_new.groupby(third_a).apply(lambda grp: grp.x_data_3 - grp.x_data_3.median()).values
plt.hist(third_df1_new.x_diff_new_3, bins=50,histtype='step' )
plt.title('Histogram: Distance Distribution from the Fiducial Line', fontsize=12)
plt.xlabel('Pixel Distance' ,fontsize=20)
plt.ylabel('Number of Stars', fontsize=20)
#plt.xlim(-0.10, 0.11)
plt.show()

#*****************************************End of F336W and F814W*******
# Out:
# 169
# 169

# %%
sns.distplot(first_df1_new.x_diff_new_1, 35,kde_kws={"color": "red", "lw": 2.5, "label": "KDE"} )
plt.xlabel('Pixel Distance', fontsize=20)
plt.ylabel('N', fontsize=20)
plt.title('Kernel Density Estimation (KDE) for NGC 411', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Kernel Density Estimation (KDE) for NGC 411')

# %%
sns.distplot(second_df1_new.x_diff_new_2, 45, kde_kws={"color": "red", "lw": 2.0, "label": "KDE"})
plt.xlabel('Pixel Distance', fontsize=20)
plt.ylabel('N', fontsize=20)
plt.title('Kernel Density Estimation (KDE) for NGC 411', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Kernel Density Estimation (KDE) for NGC 411')

# %%
sns.distplot(third_df1_new.x_diff_new_3,40,kde_kws={"color": "red", "lw": 2.5, "label": "KDE"} )
plt.xlabel('Pixel Distance', fontsize=20)
plt.ylabel('N', fontsize=20)
plt.title('Kernel Density Estimation (KDE) for NGC 411', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Kernel Density Estimation (KDE) for NGC 411')

# %%
fig1, (ax1, ax2, ax3) = plt.subplots(1, 3)
#fig.suptitle('Colour Magnitude Diagrams for NGC 411')
fig.tight_layout() 

ax1.scatter(x_data_1, y_data_1, 0.1, 'black')
ax1.plot(x_iso_1, y_iso_1, linewidth=0.5, c='yellow')
ax1.plot(x_iso_11, y_iso_11,linewidth= 0.5, c='red')
ax1.plot(x_iso_12, y_iso_12,linewidth= 0.5, c='green')
ax1.plot(x_iso_13, y_iso_13,linewidth= 0.5, c='blue')
ax1.set_xlim(-1.2,2.0)
ax1.set_ylim(18, 24.0)
ax1.invert_yaxis()
ax1.set_xlabel("F336W - F475W (mag)", fontsize=8.5)
ax1.set_ylabel("F336W (mag)", fontsize=8.5)
#plt.show()

ax2.scatter(x_data_2, y_data_2, 0.1, 'black')
ax2.plot(x_iso_2, y_iso_2,linewidth= 0.5, c='yellow')
ax2.plot(x_iso_21, y_iso_21,linewidth= 0.5, c='red')
ax2.plot(x_iso_22, y_iso_22,linewidth= 0.5, c='green')
ax2.plot(x_iso_23, y_iso_23,linewidth= 0.5, c='blue')
ax2.set_xlim(-1.2,2.3)
ax2.set_ylim(18, 24.5)
ax2.invert_yaxis()
ax2.set_xlabel("F475W - F814W (mag)", fontsize=8.5)
ax2.set_ylabel("F475W (mag)", fontsize=8.5)
#plt.show()

ax3.scatter(x_data_3, y_data_3, 0.1, 'black')
ax3.plot(x_iso_3, y_iso_3,linewidth= 0.5, c='yellow')
ax3.plot(x_iso_31, y_iso_31,linewidth= 0.5, c='red')
ax3.plot(x_iso_32, y_iso_32,linewidth= 0.5, c='green')
ax3.plot(x_iso_33, y_iso_33, linewidth=0.5, c='blue')
ax3.set_xlim(-1.2,3.3)
ax3.set_ylim(18, 24.5)
ax3.invert_yaxis()
ax3.set_xlabel("F336W - F814W (mag)", fontsize=8.5)
ax3.set_ylabel("F336W (mag)", fontsize=8.5) 
plt.show() 

#fig.text(0.5, 0.04, 'common X', ha='center')
#fig.text(0.04, 0.5, 'common Y', va='center', rotation='vertical')

# %%
fig1, (ax1, ax2, ax3) = plt.subplots(1, 3)
#fig.suptitle('Colour Magnitude Diagrams for NGC 411')
fig1.tight_layout() 
fig1.set_size_inches(19.0, 8.5) 

ax1.scatter(x_data_1, y_data_1, 1.2, 'black')
ax1.plot(x_iso_1, y_iso_1, linewidth=0.5, c='yellow')
ax1.plot(x_iso_11, y_iso_11,linewidth= 0.5, c='red')
ax1.plot(x_iso_12, y_iso_12,linewidth= 0.5, c='green')
ax1.plot(x_iso_13, y_iso_13,linewidth= 0.5, c='blue')
ax1.set_xlim(-1.2,2.0)
ax1.set_ylim(18, 24.0)
ax1.invert_yaxis()
ax1.set_xlabel("F336W - F475W (mag)", fontsize=15.5)
ax1.set_ylabel("F336W (mag)", fontsize=15.5)
#ax1.set_xticklabels( fontsize=8)
ax1.tick_params(labelsize=18)

ax2.scatter(x_data_2, y_data_2, 1.2, 'black')
ax2.plot(x_iso_2, y_iso_2,linewidth= 0.5, c='yellow')
ax2.plot(x_iso_21, y_iso_21,linewidth= 0.5, c='red')
ax2.plot(x_iso_22, y_iso_22,linewidth= 0.5, c='green')
ax2.plot(x_iso_23, y_iso_23,linewidth= 0.5, c='blue')
ax2.set_xlim(-1.2,2.2)
ax2.set_ylim(18, 24.2)
ax2.invert_yaxis()
ax2.set_xlabel("F475W - F814W (mag)", fontsize=15.5)
ax2.set_ylabel("F475W (mag)", fontsize=15.5)
ax2.tick_params(labelsize=18)

ax3.scatter(x_data_3, y_data_3, 1.2, 'black')
ax3.plot(x_iso_3, y_iso_3,linewidth= 0.5, c='yellow')
ax3.plot(x_iso_31, y_iso_31,linewidth= 0.5, c='red')
ax3.plot(x_iso_32, y_iso_32,linewidth= 0.5, c='green')
ax3.plot(x_iso_33, y_iso_33, linewidth=0.5, c='blue')
ax3.set_xlim(-1.2,3.8)
ax3.set_ylim(18, 24.5)
ax3.invert_yaxis()
ax3.set_xlabel("F336W - F814W (mag)", fontsize=15.5)
ax3.set_ylabel("F336W (mag)", fontsize=15.5) 
ax3.tick_params(labelsize=18)

fig1.tight_layout(pad=3.0) 


#fig.text(0.5, 0.04, 'common X', ha='center')
#fig.text(0.04, 0.5, 'common Y', va='center', rotation='vertical')


fig2, (ax4, ax5, ax6) = plt.subplots(1, 3)
fig2.tight_layout(pad=3.0) 
fig2.set_size_inches(10.0, 3.5)

ax4.scatter(first_df_cut.x_data_1, first_df_cut.y_data_1, 1.5, 'grey')
ax4.scatter(first_df_cut_1.x_data_1, first_df_cut_1.y_data_1,1.5, 'red')
ax4.invert_yaxis()
ax4.set_xlabel('m_F336W - m_F475W (mag)', fontsize=9)
ax4.set_ylabel('m_F336W (mag)', fontsize=14)
ax4.tick_params(labelsize=18)

ax5.scatter(second_df_cut.x_data_2, second_df_cut.y_data_2,  1.5, 'grey')
ax5.scatter(second_df_cut_1.x_data_2, second_df_cut_1.y_data_2, 1.5, 'red')
ax5.invert_yaxis()
ax5.set_xlabel('m_F475W - m_F814W (mag)', fontsize=9)
ax5.set_ylabel('m_F475W (mag)', fontsize=14)
ax5.tick_params(labelsize=18)

ax6.scatter(third_df_cut.x_data_3, third_df_cut.y_data_3,  1.5, 'grey')
ax6.scatter(third_df_cut_1.x_data_3, third_df_cut_1.y_data_3, 1.5, 'red')
ax6.invert_yaxis()
ax6.set_xlabel('m_F336W - m_F814W (mag)', fontsize=9)
ax6.set_ylabel('m_F336W (mag)', fontsize=14)
ax6.tick_params(labelsize=18)

fig3, (ax7, ax8, ax9) = plt.subplots(1, 3)
fig3.tight_layout(pad=3.0) 
fig3.set_size_inches(10.0, 3.5)



ax7.plot(md_1['x_med'], md_1['y_med'], 'red')
ax7.grid()
ax7.scatter(first_df1_new['x_data_1'], first_df1_new['y_data_1'], 2.2, 'grey', zorder=0)
ax7.invert_yaxis()
ax7.set_xlabel('m_F336W - m_F475W (mag)', fontsize=9)
ax7.set_ylabel('m_F336W (mag)', fontsize=9)
ax7.tick_params(labelsize=18)

ax8.plot(md_2['x_med'], md_2['y_med'], 'red')
ax8.grid()
ax8.scatter(second_df1_new['x_data_2'], second_df1_new['y_data_2'], 2.2, 'grey', zorder=0)
ax8.invert_yaxis()
ax8.set_xlabel('m_F336W - m_F475W (mag)', fontsize=9)
ax8.set_ylabel('m_F336W (mag)', fontsize=9)
ax8.tick_params(labelsize=18)

ax9.plot(md_3['x_med'], md_3['y_med'], 'red')
ax9.grid()
ax9.scatter(third_df1_new['x_data_3'], third_df1_new['y_data_3'], 2.2, 'grey', zorder=0)
ax9.invert_yaxis()
ax9.set_xlabel('m_F336W - m_F475W (mag)', fontsize=9)
ax9.set_ylabel('m_F336W (mag)', fontsize=9)
ax9.tick_params(labelsize=18)


fig4, (ax10, ax11, ax12) = plt.subplots(1, 3)
fig4.tight_layout(pad=1.0) 
fig4.set_size_inches(15.0, 3.5)

#plt.xlabel('Pixel Distance' ,fontsize=20)
#plt.ylabel('Number of Stars', fontsize=20)

ax10.hist(first_df1_new.x_diff_new_1, bins=50,histtype='step' )
ax10.set_xlabel("Pixel Distance", fontsize=12)
ax10.set_ylabel("Number of Stars", fontsize=12)
ax10.tick_params(labelsize=18)

ax11.hist(second_df1_new.x_diff_new_2, bins=50,histtype='step' )
ax11.set_xlabel("Pixel Distance", fontsize=12)
ax11.set_ylabel("Number of Stars", fontsize=12)
ax11.tick_params(labelsize=18)

ax12.hist(third_df1_new.x_diff_new_3, bins=50,histtype='step' )
ax12.set_xlabel("Pixel Distance", fontsize=12)
ax12.set_ylabel("Number of Stars", fontsize=12)
ax12.tick_params(labelsize=18)

# %%
fig2, (ax4, ax5, ax6) = plt.subplots(1, 3)
fig2.tight_layout(pad=3.0) 
fig2.set_size_inches(10.0, 3.5)

ax4.scatter(first_df_cut.x_data_1, first_df_cut.y_data_1, 1.5, 'red')
ax4.scatter(first_df_cut_1.x_data_1, first_df_cut_1.y_data_1,1.5, 'grey')
ax4.invert_yaxis()
ax4.set_xlabel('m_F336W - m_F475W (mag)', fontsize=9)
ax4.set_ylabel('m_F336W (mag)', fontsize=14)

ax5.scatter(second_df_cut.x_data_2, second_df_cut.y_data_2,  1.5, 'red')
ax5.scatter(second_df_cut_1.x_data_2, second_df_cut_1.y_data_2, 1.5, 'grey')
ax5.invert_yaxis()
ax5.set_xlabel('m_F475W - m_F814W (mag)', fontsize=9)
ax5.set_ylabel('m_F475W (mag)', fontsize=14)

ax6.scatter(third_df_cut.x_data_3, third_df_cut.y_data_3,  1.5, 'red')
ax6.scatter(third_df_cut_1.x_data_3, third_df_cut_1.y_data_3, 1.5, 'grey')
ax6.invert_yaxis()
ax6.set_xlabel('m_F336W - m_F814W (mag)', fontsize=9)
ax6.set_ylabel('m_F336W (mag)', fontsize=14)
# Out:
# Text(392.83986928104576, 0.5, 'm_F336W (mag)')

# %%
fig3, (ax7, ax8, ax9) = plt.subplots(1, 3)
fig3.tight_layout(pad=3.0) 
fig3.set_size_inches(10.0, 3.5)



ax7.plot(md_1['x_med'], md_1['y_med'], 'red')
ax7.grid()
ax7.scatter(first_df1_new['x_data_1'], first_df1_new['y_data_1'], 2.2, 'grey', zorder=0)
ax7.invert_yaxis()
ax7.set_xlabel('m_F336W - m_F475W (mag)', fontsize=9)
ax7.set_ylabel('m_F336W (mag)', fontsize=9)

ax8.plot(md_2['x_med'], md_2['y_med'], 'red')
ax8.grid()
ax8.scatter(second_df1_new['x_data_2'], second_df1_new['y_data_2'], 2.2, 'grey', zorder=0)
ax8.invert_yaxis()
ax8.set_xlabel('m_F336W - m_F475W (mag)', fontsize=9)
ax8.set_ylabel('m_F336W (mag)', fontsize=9)

ax9.plot(md_3['x_med'], md_3['y_med'], 'red')
ax9.grid()
ax9.scatter(third_df1_new['x_data_3'], third_df1_new['y_data_3'], 2.2, 'grey', zorder=0)
ax9.invert_yaxis()
ax9.set_xlabel('m_F336W - m_F475W (mag)', fontsize=9)
ax9.set_ylabel('m_F336W (mag)', fontsize=9)
# Out:
# Text(392.83986928104576, 0.5, 'm_F336W (mag)')

# %%
fig4, (ax10, ax11, ax12) = plt.subplots(1, 3)
fig4.tight_layout(pad=1.0) 
fig4.set_size_inches(15.0, 3.5)

#plt.xlabel('Pixel Distance' ,fontsize=20)
#plt.ylabel('Number of Stars', fontsize=20)

ax10.hist(first_df1_new.x_diff_new_1, bins=50,histtype='step' )
ax10.set_xlabel("Pixel Distance", fontsize=12)
ax10.set_ylabel("Number of Stars", fontsize=12)

ax11.hist(second_df1_new.x_diff_new_2, bins=50,histtype='step' )
ax11.set_xlabel("Pixel Distance", fontsize=12)
ax11.set_ylabel("Number of Stars", fontsize=12)


ax12.hist(third_df1_new.x_diff_new_3, bins=50,histtype='step' )
ax12.set_xlabel("Pixel Distance", fontsize=12)
ax12.set_ylabel("Number of Stars", fontsize=12)
# Out:
# Text(392.83986928104576, 0.5, 'Number of Stars')
